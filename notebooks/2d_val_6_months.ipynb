# %%
import pandas as pd
import sys

sys.path.append('../python_scripts')
run_name = '2d_val_6_months_1'

# %%
df_median = pd.read_parquet("../sim_results/{}/median_objectives".format(run_name))
df_median.to_parquet('../sim_results/{}/median_objectives.parquet'.format(run_name))

# %%
df = pd.read_parquet('../sim_results/{}/median_objectives.parquet'.format(run_name)).reset_index()

# %%
df_train_regret = df.loc[(df['mode'] == 'train') & (df.objective == 'mean_regret')]
df_val_regret = df.loc[(df['mode'] == 'val') & (df.objective == 'mean_regret')]
df_val = df.loc[(df['mode'] == 'val') & (df.objective == 'mean')]
df_train = df.loc[(df['mode'] == 'train') & (df.objective == 'mean')]

s_train = df_train[['gen', 'value']].groupby('gen').agg('mean').iloc[:,0].sort_index()
s_train_regret = df_train_regret[['gen', 'value']].groupby('gen').agg('mean').iloc[:,0].sort_index()
s_val_regret = df_val_regret[['gen', 'value']].groupby('gen').agg('mean').iloc[:, 0].sort_index()
s_val = df_val[['gen', 'value']].groupby('gen').agg('mean').iloc[:, 0].sort_index()

# %%
import plotly.graph_objects as go 

fig = go.Figure()
fig.add_trace(go.Scatter(x = s_train_regret.index.values, y = s_train_regret.values, name = 'train_regret'))
fig.add_trace(go.Scatter(x = s_val_regret.index, y = s_val_regret.values, name = 'val_regret'))
fig.add_trace(go.Scatter(x = s_val.index, y = s_val.values, name = 'val'))
fig.add_trace(go.Scatter(x = s_train.index, y = s_train.values, name = 'train'))
fig.show()

# %%
from utils import get_pareto_layers

df_pareto = pd.DataFrame()
df_1  = pd.DataFrame()
for gen in df['gen'].drop_duplicates():
    df_gen = df.loc[df['gen'] == gen]
    df_pivot = pd.pivot_table(df_gen[['mode', 'objective', 'sim_id', 'value']], index = 'sim_id', values = 'value', columns = ['mode', 'objective'])
    df_layers = get_pareto_layers(df_pivot[[('train','mean_regret'), ('train','regret_quantile')]], sense = ['min', 'min'], num_layers=1)
    pareto_indices = df_layers.loc[df_layers.layer==0].index
    df_add = df_pivot.loc[pareto_indices]
    df_add['gen'] = gen
    argmin = int(df_add[('train', 'mean_regret')].argmin())
    df_add_1 = pd.DataFrame(df_add.iloc[argmin]).transpose() 
    df_1 = pd.concat([df_1, df_add_1])
    df_pareto = pd.concat([df_pareto, df_add])
    
df_pareto.to_parquet('../sim_results/{}/train_pareto_by_gen.parquet'.format(run_name))

# %%
#ALTERNATIVE
from utils import get_pareto_layers

df_pareto = pd.DataFrame()
df_1  = pd.DataFrame()
for gen in sorted(list(df['gen'].drop_duplicates())):
    df_gen = df.loc[df['gen'] == gen]
    df_pivot = pd.pivot_table(df_gen[['mode', 'objective', 'sim_id', 'value']], index = 'sim_id', values = 'value', columns = ['mode', 'objective'])
    #df_layers = get_pareto_layers(df_pivot[[('train','mean_regret'), ('train','regret_quantile')]], sense = ['min', 'min'], num_layers=1)
    #pareto_indices = df_layers.loc[df_layers.layer==0].index
    df_add = df_pivot
    df_add['gen'] = gen
    argmin = int(df_add[('train', 'mean_regret')].argmin())
    df_add_1 = pd.DataFrame(df_add.iloc[argmin]).transpose()
    df_add_1['sim_id'] = df_add_1.index
    df_1 = pd.concat([df_1, df_add_1])
    df_pareto = pd.concat([df_pareto, df_add])
   
    
    
df_pareto.to_parquet('../sim_results/{}/train_pareto_by_gen.parquet'.format(run_name))

# %%
df_1.gen.max()
# Out:
# np.float64(86.0)

# %%
import numpy as np
sim_id = df_1.loc[df_1.gen == max(df_1.gen)].index[0]
s_values = pd.read_parquet('s3://jdinvestment/{}/portfolio_values/sim_{}.parquet'.format(run_name, sim_id)).transpose().iloc[:-2]
df_pop = pd.read_parquet("s3://jdinvestment/{}/populations/gen_86.parquet".format(run_name))
sim_index = int(np.where(df_pop.index == sim_id)[0][0])
print(sim_index, sim_id, (s_values.iloc[-1]/s_values.iloc[-14])**(1/1), s_values.index[-14], s_values.index[-1])
# Out:
# 87 a32fab5f076b a32fab5f076b    0.027638
# dtype: object 2025-08-11_00:00:00 2026-08-10_00:00:00

# %%
sim_id in df_pop
# Out:
# False

# %%
import pandas as pd
df_history = pd.read_parquet('s3://jdinvestment/{}/holdings/sim_{}.parquet'.format(run_name, sim_id))
s_value = df_history.set_index('date').drop('sim_id', axis = 1).sum(1).iloc[:-1]
s_value.iloc[-1], s_value.iloc[-6], s_value.iloc[-6:]
(s_value.iloc[-2]/s_value.iloc[-6])**(13/4)
# Out:
# np.float64(1.090032042873225)

# %%
print((s_values.iloc[-2]/s_values.iloc[-7]).iloc[0]**(13/5))
print(s_values.iloc[-8:-1]), s_values.iloc[-7], s_values.iloc[-2]
# Out:
# 1.0203606516776806
#                       a32fab5f076b
# date
# 2026-01-26_00:00:00  12020559.8804
# 2026-02-23_00:00:00   12405151.031
# 2026-03-23_00:00:00  11867570.2812
# 2026-04-20_00:00:00  12562382.6169
# 2026-05-18_00:00:00  12588893.6516
# 2026-06-15_00:00:00  12738603.7891
# 2026-07-13_00:00:00  12501694.0046
# (None,
#  a32fab5f076b    12405151.031
#  Name: 2026-02-23_00:00:00, dtype: object,
#  a32fab5f076b    12501694.0046
#  Name: 2026-07-13_00:00:00, dtype: object)

# %%
s_values.iloc[-15:]
125/127
# Out:
# 0.984251968503937

# %%
s_train_regret = (df_pareto[[('train', 'mean_regret'), ('gen','')]]).groupby('gen').agg('mean').iloc[:,0]
s_val_regret = (df_pareto[[('val', 'mean_regret'), ('gen','')]]).groupby('gen').agg('mean').iloc[:,0]
s_val= (df_pareto[[('val', 'mean'), ('gen','')]]).groupby('gen').agg('mean').iloc[:,0]
fig = go.Figure()
fig.add_trace(go.Scatter(x = s_train_regret.index.values, y = s_train_regret.values, name = 'train_regret'))
fig.add_trace(go.Scatter(x = s_val_regret.index, y = s_val_regret.values, name = 'val_regret'))
fig.add_trace(go.Scatter(x = s_val.index, y = s_val.values, name = 'val'))
fig.show()

# %%
df_1.columns
# Out:
# MultiIndex([('train',            'mean'),
#             ('train',     'mean_regret'),
#             ('train',        'quantile'),
#             ('train', 'regret_quantile'),
#             (  'val',            'mean'),
#             (  'val',     'mean_regret'),
#             (  'val',        'quantile'),
#             (  'val', 'regret_quantile'),
#             (  'gen',                '')],
#            names=['mode', 'objective'])
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import plotly.graph_objects as go 
s_train_regret = (df_1[[('train', 'mean_regret'), ('gen','')]]).groupby('gen').agg('mean').iloc[:,0]
s_val_regret = (df_1[[('val', 'mean_regret'), ('gen','')]]).groupby('gen').agg('mean').iloc[:,0]
s_val = (df_1[[('val', 'mean'), ('gen','')]]).groupby('gen').agg('mean').iloc[:,0]
fig = go.Figure()
fig.add_trace(go.Scatter(x = s_train_regret.index.values, y = s_train_regret.values, name = 'train_regret'))
fig.add_trace(go.Scatter(x = s_val_regret.index, y = s_val_regret.values, name = 'val_regret'))
fig.add_trace(go.Scatter(x = s_val.index, y = s_val.values, name = 'val'))
fig.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import xarray as xr
import pandas as pd
s_voo = xr.open_dataset('../simulation_data/momentum.nc').to_array()[0].sel(symbol = 'VOO', band = 'price_end').to_pandas()
fold_index = 4
df_folds = pd.read_parquet('../strategy/folds.parquet')
df_fold = df_folds.loc[df_folds.fold_index == fold_index]

# %%
import functools
from objective_functions import mean_annualized_return, WeightedRegimeApplyer, weighted_mean


start_date = min(df_fold.start_date)
end_date = max(df_fold.end_date)
agg_func = functools.partial(mean_annualized_return, start_date, end_date)

voo_func = WeightedRegimeApplyer(df_fold, agg_func, weighted_mean)
voo_mean = voo_func(s_voo)
voo_mean
# Out:
# np.float64(0.15859726102530505)

# %%
import functools
from objective_functions import mean_annualized_return, WeightedRegimeApplyer, weighted_mean
df_folds = pd.read_csv('../strategy/folds_1.csv')
for col in ['start_date', 'end_date']:
    df_folds[col] = pd.to_datetime(df_folds[col])
df_voo = pd.read_csv('../simulation_data/voo_backcasted_28days.csv')
s_voo = pd.Series(df_voo.values[:,-1], index = pd.to_datetime(df_voo.iloc[:,0]))
df_out = pd.DataFrame()
for row in range(df_folds.shape[0]):
    df_fold = df_folds.iloc[row].copy()
    start_date, end_date = df_fold[['start_date', 'end_date']]
    

    
    voo_mean = mean_annualized_return(start_date, end_date,s_voo)
    df_fold['voo_return'] = voo_mean
    df_out = pd.concat([df_out, pd.DataFrame(df_fold.copy()).transpose()])
    print(start_date, end_date, voo_mean)
df_out = df_out.rename(columns = {'index': 'description'}).set_index('description')
print(df_out)
# Out:
# 2008-01-01 00:00:00 2008-08-31 00:00:00 -0.08560702196953351
# 2008-09-01 00:00:00 2009-03-31 00:00:00 -0.6255475194744984
# 2009-04-01 00:00:00 2009-12-31 00:00:00 0.4579419345017437
# 2010-01-01 00:00:00 2011-04-30 00:00:00 0.13197869183563848
# 2011-05-01 00:00:00 2011-11-30 00:00:00 -0.18230933045622366
# 2011-12-01 00:00:00 2013-04-30 00:00:00 0.248253698361115
# 2013-05-01 00:00:00 2013-12-31 00:00:00 0.20293260341316
# 2014-01-01 00:00:00 2015-07-31 00:00:00 0.10908982197281247
# 2015-08-01 00:00:00 2016-02-29 00:00:00 -0.022362341330139923
# 2016-03-01 00:00:00 2017-12-31 00:00:00 0.19914092503598924
# 2018-01-01 00:00:00 2018-03-31 00:00:00 -0.039952295425778384
# 2018-04-01 00:00:00 2018-09-30 00:00:00 0.30276171252467443
# 2018-10-01 00:00:00 2018-12-31 00:00:00 -0.2247335172284438
# 2019-01-01 00:00:00 2020-01-31 00:00:00 0.2997640483772288
# 2020-02-01 00:00:00 2020-04-30 00:00:00 -0.3967135888024208
# 2020-05-01 00:00:00 2021-12-31 00:00:00 0.3420393562675983
# 2022-01-01 00:00:00 2022-09-30 00:00:00 -0.187190713633831
# 2022-10-01 00:00:00 2023-06-30 00:00:00 0.34987337435014987
# 2023-07-01 00:00:00 2024-03-31 00:00:00 0.2503389791657229
# 2024-04-01 00:00:00 2024-05-31 00:00:00 1.17064496026694
# 2024-06-01 00:00:00 2024-08-31 00:00:00 -0.1357111896941816
# 2024-09-01 00:00:00 2025-06-30 00:00:00 0.15117633221536786
# 2025-07-01 00:00:00 2025-08-31 00:00:00 0.2576541928536531
# 2025-09-01 00:00:00 2025-11-30 00:00:00 0.42879291269441167
# 2025-12-01 00:00:00 2026-02-28 00:00:00 0.027277643740870383
# 2026-03-01 00:00:00 2026-04-30 00:00:00 1.7716992733461008
#                                                              start_date  \
# description
# Early GFC Recession (Pre-Lehman)                    2008-01-01 00:00:00
# GFC Panic Apex (Lehman to Market Bottom)            2008-09-01 00:00:00
# Transition: Liquidity-Driven Early Recovery         2009-04-01 00:00:00
# Mid-Cycle Expansion & QE1/QE2                       2010-01-01 00:00:00
# Transition: Euro Sovereign Debt & US Downgrade      2011-05-01 00:00:00
# Draghi "Whatever It Takes" Stabilization            2011-12-01 00:00:00
# Transition: Taper Tantrum Rate Shock                2013-05-01 00:00:00
# US Decoupling & Strong Dollar Inflow                2014-01-01 00:00:00
# Transition: China Devaluation & Oil Crash           2015-08-01 00:00:00
# Post-Election Reflation & Low-Vol Goldilocks        2016-03-01 00:00:00
# Transition: Volmageddon Short-Volatility Squeeze    2018-01-01 00:00:00
# Trade War Escalation & Synchronized Slowdown        2018-04-01 00:00:00
# Transition: Fed "Long Way From Neutral" Hawk Crash  2018-10-01 00:00:00
# Fed Dovish Pivot & Insurance Rate Cuts              2019-01-01 00:00:00
# Transition: COVID-19 Flash Liquidation Shock        2020-02-01 00:00:00
# Hyper-Stimulus Recovery & Retail Euphoria           2020-05-01 00:00:00
# Transition: Great Inflation & Aggressive Fed Hikes  2022-01-01 00:00:00
# Yield Curve Inversion Deepening & SVB Banking C...  2022-10-01 00:00:00
# Generative AI Boom & Soft-Landing Narrative         2023-07-01 00:00:00
# Transition: Sticky Inflation/Bumper Yield Spike     2024-04-01 00:00:00
# Mega-Cap Momentum Concentration Flight              2024-06-01 00:00:00
# Fed Rate Cutting Cycle & Macro Stabilization        2024-09-01 00:00:00
# Transition: Technical Derivative & Gamma Unwind...  2025-07-01 00:00:00
# Credit Realignment & Sovereign Spread Creep         2025-09-01 00:00:00
# Fiscal Horizon Reset & Volatility Compression       2025-12-01 00:00:00
# Transition: Margin Deleveraging Ripple              2026-03-01 00:00:00
#
#                                                                end_date  \
# description
# Early GFC Recession (Pre-Lehman)                    2008-08-31 00:00:00
# GFC Panic Apex (Lehman to Market Bottom)            2009-03-31 00:00:00
# Transition: Liquidity-Driven Early Recovery         2009-12-31 00:00:00
# Mid-Cycle Expansion & QE1/QE2                       2011-04-30 00:00:00
# Transition: Euro Sovereign Debt & US Downgrade      2011-11-30 00:00:00
# Draghi "Whatever It Takes" Stabilization            2013-04-30 00:00:00
# Transition: Taper Tantrum Rate Shock                2013-12-31 00:00:00
# US Decoupling & Strong Dollar Inflow                2015-07-31 00:00:00
# Transition: China Devaluation & Oil Crash           2016-02-29 00:00:00
# Post-Election Reflation & Low-Vol Goldilocks        2017-12-31 00:00:00
# Transition: Volmageddon Short-Volatility Squeeze    2018-03-31 00:00:00
# Trade War Escalation & Synchronized Slowdown        2018-09-30 00:00:00
# Transition: Fed "Long Way From Neutral" Hawk Crash  2018-12-31 00:00:00
# Fed Dovish Pivot & Insurance Rate Cuts              2020-01-31 00:00:00
# Transition: COVID-19 Flash Liquidation Shock        2020-04-30 00:00:00
# Hyper-Stimulus Recovery & Retail Euphoria           2021-12-31 00:00:00
# Transition: Great Inflation & Aggressive Fed Hikes  2022-09-30 00:00:00
# Yield Curve Inversion Deepening & SVB Banking C...  2023-06-30 00:00:00
# Generative AI Boom & Soft-Landing Narrative         2024-03-31 00:00:00
# Transition: Sticky Inflation/Bumper Yield Spike     2024-05-31 00:00:00
# Mega-Cap Momentum Concentration Flight              2024-08-31 00:00:00
# Fed Rate Cutting Cycle & Macro Stabilization        2025-06-30 00:00:00
# Transition: Technical Derivative & Gamma Unwind...  2025-08-31 00:00:00
# Credit Realignment & Sovereign Spread Creep         2025-11-30 00:00:00
# Fiscal Horizon Reset & Volatility Compression       2026-02-28 00:00:00
# Transition: Margin Deleveraging Ripple              2026-04-30 00:00:00
#
#                                                    fold_index  \
# description
# Early GFC Recession (Pre-Lehman)                            1
# GFC Panic Apex (Lehman to Market Bottom)                    3
# Transition: Liquidity-Driven Early Recovery                 0
# Mid-Cycle Expansion & QE1/QE2                               3
# Transition: Euro Sovereign Debt & US Downgrade              0
# Draghi "Whatever It Takes" Stabilization                    3
# Transition: Taper Tantrum Rate Shock                        3
# US Decoupling & Strong Dollar Inflow                        2
# Transition: China Devaluation & Oil Crash                   2
# Post-Election Reflation & Low-Vol Goldilocks                0
# Transition: Volmageddon Short-Volatility Squeeze            3
# Trade War Escalation & Synchronized Slowdown                1
# Transition: Fed "Long Way From Neutral" Hawk Crash          0
# Fed Dovish Pivot & Insurance Rate Cuts                      2
# Transition: COVID-19 Flash Liquidation Shock                2
# Hyper-Stimulus Recovery & Retail Euphoria                   1
# Transition: Great Inflation & Aggressive Fed Hikes          0
# Yield Curve Inversion Deepening & SVB Banking C...          2
# Generative AI Boom & Soft-Landing Narrative                 1
# Transition: Sticky Inflation/Bumper Yield Spike             0
# Mega-Cap Momentum Concentration Flight                      3
# Fed Rate Cutting Cycle & Macro Stabilization                1
# Transition: Technical Derivative & Gamma Unwind...          4
# Credit Realignment & Sovereign Spread Creep                 4
# Fiscal Horizon Reset & Volatility Compression               4
# Transition: Margin Deleveraging Ripple                      4
#
#                                                                                 fold_name  \
# description
# Early GFC Recession (Pre-Lehman)                               Recovery & Policy Response
# GFC Panic Apex (Lehman to Market Bottom)            Policy Stabilization & Systemic Panic
# Transition: Liquidity-Driven Early Recovery                     Reflation & Market Stress
# Mid-Cycle Expansion & QE1/QE2                       Policy Stabilization & Systemic Panic
# Transition: Euro Sovereign Debt & US Downgrade                  Reflation & Market Stress
# Draghi "Whatever It Takes" Stabilization            Policy Stabilization & Systemic Panic
# Transition: Taper Tantrum Rate Shock                Policy Stabilization & Systemic Panic
# US Decoupling & Strong Dollar Inflow                Macro Expansion & Structural Slowdown
# Transition: China Devaluation & Oil Crash           Macro Expansion & Structural Slowdown
# Post-Election Reflation & Low-Vol Goldilocks                    Reflation & Market Stress
# Transition: Volmageddon Short-Volatility Squeeze    Policy Stabilization & Systemic Panic
# Trade War Escalation & Synchronized Slowdown                   Recovery & Policy Response
# Transition: Fed "Long Way From Neutral" Hawk Crash              Reflation & Market Stress
# Fed Dovish Pivot & Insurance Rate Cuts              Macro Expansion & Structural Slowdown
# Transition: COVID-19 Flash Liquidation Shock        Macro Expansion & Structural Slowdown
# Hyper-Stimulus Recovery & Retail Euphoria                      Recovery & Policy Response
# Transition: Great Inflation & Aggressive Fed Hikes              Reflation & Market Stress
# Yield Curve Inversion Deepening & SVB Banking C...  Macro Expansion & Structural Slowdown
# Generative AI Boom & Soft-Landing Narrative                    Recovery & Policy Response
# Transition: Sticky Inflation/Bumper Yield Spike                 Reflation & Market Stress
# Mega-Cap Momentum Concentration Flight              Policy Stabilization & Systemic Panic
# Fed Rate Cutting Cycle & Macro Stabilization                   Recovery & Policy Response
# Transition: Technical Derivative & Gamma Unwind...                              Test Data
# Credit Realignment & Sovereign Spread Creep                                     Test Data
# Fiscal Horizon Reset & Volatility Compression                                   Test Data
# Transition: Margin Deleveraging Ripple                                          Test Data
#
#                                                    max_annualized_return  \
# description
# Early GFC Recession (Pre-Lehman)                                0.303544
# GFC Panic Apex (Lehman to Market Bottom)                        0.112335
# Transition: Liquidity-Driven Early Recovery                     0.523215
# Mid-Cycle Expansion & QE1/QE2                                   0.445027
# Transition: Euro Sovereign Debt & US Downgrade                 -0.035835
# Draghi "Whatever It Takes" Stabilization                        0.405525
# Transition: Taper Tantrum Rate Shock                            0.544122
# US Decoupling & Strong Dollar Inflow                            0.212598
# Transition: China Devaluation & Oil Crash                       0.230798
# Post-Election Reflation & Low-Vol Goldilocks                      0.3941
# Transition: Volmageddon Short-Volatility Squeeze                0.487606
# Trade War Escalation & Synchronized Slowdown                    0.520187
# Transition: Fed "Long Way From Neutral" Hawk Crash              0.423978
# Fed Dovish Pivot & Insurance Rate Cuts                          0.460413
# Transition: COVID-19 Flash Liquidation Shock                    0.557543
# Hyper-Stimulus Recovery & Retail Euphoria                       0.611839
# Transition: Great Inflation & Aggressive Fed Hikes              0.451229
# Yield Curve Inversion Deepening & SVB Banking C...              0.646462
# Generative AI Boom & Soft-Landing Narrative                     0.516881
# Transition: Sticky Inflation/Bumper Yield Spike                 2.212921
# Mega-Cap Momentum Concentration Flight                          1.464405
# Fed Rate Cutting Cycle & Macro Stabilization                    1.718005
# Transition: Technical Derivative & Gamma Unwind...                   NaN
# Credit Realignment & Sovereign Spread Creep                          NaN
# Fiscal Horizon Reset & Volatility Compression                        NaN
# Transition: Margin Deleveraging Ripple                               NaN
#
#                                                    voo_return
# description
# Early GFC Recession (Pre-Lehman)                    -0.085607
# GFC Panic Apex (Lehman to Market Bottom)            -0.625548
# Transition: Liquidity-Driven Early Recovery          0.457942
# Mid-Cycle Expansion & QE1/QE2                        0.131979
# Transition: Euro Sovereign Debt & US Downgrade      -0.182309
# Draghi "Whatever It Takes" Stabilization             0.248254
# Transition: Taper Tantrum Rate Shock                 0.202933
# US Decoupling & Strong Dollar Inflow                  0.10909
# Transition: China Devaluation & Oil Crash           -0.022362
# Post-Election Reflation & Low-Vol Goldilocks         0.199141
# Transition: Volmageddon Short-Volatility Squeeze    -0.039952
# Trade War Escalation & Synchronized Slowdown         0.302762
# Transition: Fed "Long Way From Neutral" Hawk Crash  -0.224734
# Fed Dovish Pivot & Insurance Rate Cuts               0.299764
# Transition: COVID-19 Flash Liquidation Shock        -0.396714
# Hyper-Stimulus Recovery & Retail Euphoria            0.342039
# Transition: Great Inflation & Aggressive Fed Hikes  -0.187191
# Yield Curve Inversion Deepening & SVB Banking C...   0.349873
# Generative AI Boom & Soft-Landing Narrative          0.250339
# Transition: Sticky Inflation/Bumper Yield Spike      1.170645
# Mega-Cap Momentum Concentration Flight              -0.135711
# Fed Rate Cutting Cycle & Macro Stabilization         0.151176
# Transition: Technical Derivative & Gamma Unwind...   0.257654
# Credit Realignment & Sovereign Spread Creep          0.428793
# Fiscal Horizon Reset & Volatility Compression        0.027278
# Transition: Margin Deleveraging Ripple               1.771699

# %%
mid_point = df_out.start_date.min() + pd.Timedelta(days = .75 * (pd.to_datetime('Jan 1, 2025') - df_out.start_date.min()).days)
mid_point
# Out:
# Timestamp('2020-10-01 12:00:00')

# %%
df_out.to_csv('../strategy/folds_2.csv')
for col in ['start_date', 'end_date']:
    df_out[col] = pd.to_datetime(df_out[col])

# %%
df2 = df_out.copy()

df2['fold_index'] = 1
df2.loc[df2.start_date <= pd.to_datetime('2020-05-01'),'fold_index'] = 0
df2.loc[df2.start_date >= pd.to_datetime('2024-09-01'), 'fold_index'] =2
df2.to_parquet('../strategy/folds_1.parquet')

# %%
pd.to_datetime(df_out.end_date)
# Out:
# description
# Early GFC Recession (Pre-Lehman)                        2008-08-31
# GFC Panic Apex (Lehman to Market Bottom)                2009-03-31
# Transition: Liquidity-Driven Early Recovery             2009-12-31
# Mid-Cycle Expansion & QE1/QE2                           2011-04-30
# Transition: Euro Sovereign Debt & US Downgrade          2011-11-30
# Draghi "Whatever It Takes" Stabilization                2013-04-30
# Transition: Taper Tantrum Rate Shock                    2013-12-31
# US Decoupling & Strong Dollar Inflow                    2015-07-31
# Transition: China Devaluation & Oil Crash               2016-02-29
# Post-Election Reflation & Low-Vol Goldilocks            2017-12-31
# Transition: Volmageddon Short-Volatility Squeeze        2018-03-31
# Trade War Escalation & Synchronized Slowdown            2018-09-30
# Transition: Fed "Long Way From Neutral" Hawk Crash      2018-12-31
# Fed Dovish Pivot & Insurance Rate Cuts                  2020-01-31
# Transition: COVID-19 Flash Liquidation Shock            2020-04-30
# Hyper-Stimulus Recovery & Retail Euphoria               2021-12-31
# Transition: Great Inflation & Aggressive Fed Hikes      2022-09-30
# Yield Curve Inversion Deepening & SVB Banking Crack     2023-06-30
# Generative AI Boom & Soft-Landing Narrative             2024-03-31
# Transition: Sticky Inflation/Bumper Yield Spike         2024-05-31
# Mega-Cap Momentum Concentration Flight                  2024-08-31
# Fed Rate Cutting Cycle & Macro Stabilization            2025-06-30
# Transition: Technical Derivative & Gamma Unwind Panic   2025-08-31
# Credit Realignment & Sovereign Spread Creep             2025-11-30
# Fiscal Horizon Reset & Volatility Compression           2026-02-28
# Transition: Margin Deleveraging Ripple                  2026-04-30
# Name: end_date, dtype: datetime64[ns]

# %%
sim_id = df_1.index[-1]
s3_path = "s3://jdinvestment/{}/portfolio_values/sim_{}.parquet".format(run_name, sim_id)
s_values = pd.read_parquet(s3_path).transpose().iloc[:-2,0]
s_values.index = pd.to_datetime(s_values.index.str.replace('_',' '))
opt_mean = voo_func(s_values)
sim_id, opt_mean, sim_id in df_1.index
# Out:
# ('15c81be3b60f', np.float64(-0.03826888266447126), True)

# %%
import numpy as np
df_pop = pd.read_parquet('../sim_results/{}/populations/gen_149.parquet'.format(run_name))
sim_index = np.where(df_pop.index == sim_id)[0][0]
sim_index
# Out:
# np.int64(176)

# %%
sim_id in df_1.index
# Out:
# True

# %%
df_holdings = pd.read_parquet('s3://jdinvestment/2d_test_fold_2/holdings/sim_a99516312234.parquet')

# %%
df19 = df_holdings.loc[df_holdings.date.dt.year == 2019].set_index('date')
df19.index = pd.to_datetime(df19.index)
df19.drop('sim_id', axis = 1, inplace = True)
df19 = pd.DataFrame(df19.values/df19.values.sum(1).reshape(df19.shape[0],1), index = df19.index, columns = df19.columns)
df19 = df19.loc[:, df19.max(0) > 0]
df19.mean(0).sort_index(ascending = False)
# Out:
# symbol
# XOM     0.007691
# XLG     0.003846
# WPC     0.003844
# WM      0.007689
# VRTX    0.003846
# VRT     0.008142
# TSLA    0.003846
# TMUS    0.026552
# STAG    0.007692
# SCHG    0.042308
# RSG     0.008693
# REXR    0.011538
# PLD     0.015381
# PGR     0.015384
# ORLY    0.042306
# O       0.007691
# NNN     0.003846
# MSFT    0.011536
# MPWR    0.013926
# MPC     0.007692
# LLY     0.003846
# KLAC    0.003846
# KKR     0.003848
# GILD    0.003844
# GIC     0.445235
# FR      0.000002
# FICO    0.010030
# EXEL    0.003846
# EGP     0.011533
# DECK    0.049999
# DBMF    0.003847
# CWST    0.046150
# CVX     0.011535
# CASY    0.000201
# BX      0.030769
# BTAL    0.011539
# BKNG    0.026917
# ARES    0.042306
# APO     0.019229
# APH     0.010338
# ADC     0.007692
# dtype: float64

# %%
df_pop = pd.read_parquet('../sim_results/2d_test_fold_2/populations/gen_149.parquet')
df_pop.shape
# Out:
# (215, 21)

# %%
sim_id
# Out:
# 'a99516312234'
