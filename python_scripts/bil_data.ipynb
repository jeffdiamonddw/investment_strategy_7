# %%
import pandas as pd
import plotly.express as px
df = pd.read_parquet('../temp/bil_data.parquet')

fig = px.scatter(x = df.index, y = df.iloc[:,0])
fig.show()

# %%
df
# Out:
#                 0
# date
# 2007-09-03  45.99
# 2007-10-01  45.79
# 2007-10-29  45.93
# 2007-11-26  45.92
# 2007-12-24  45.93
# ...           ...
# 2026-03-23  91.58
# 2026-04-20  91.56
# 2026-05-18  91.53
# 2026-06-15  91.51
# 2026-07-13  91.50
#
# [247 rows x 1 columns]
